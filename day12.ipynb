# %%
import itertools

# testvalues
# moonPos = {"A":[-1, 0, 2], "B":[2,  -10, -7], "C":[4,  -8,  8], "D":[3,  5,   -1]}

moonPos = {"A":[19, -10, 7], "B":[1, 2, -3], "C":[14, -4, 1], "D":[8, 7, -6]}
allX1 = [19,1,14,8]
allY1 = [-10,2,-4,7]
allZ1 = [7,-3,1,-6]
moonVel = {"A":[0, 0, 0], "B":[0, 0, 0], "C":[0, 0, 0], "D":[0, 0, 0]}

# %%
for i in range(1000):
    perms = itertools.combinations(moonPos,2)
    for moonPerm in perms:
        compA = moonPos[moonPerm[0]]
        compB = moonPos[moonPerm[1]]
        velA  = moonVel[moonPerm[0]]
        velB  = moonVel[moonPerm[1]]

        for j in range(3):
            if compA[j] > compB[j]:
                velA[j] -= 1
                velB[j] += 1
            elif compA[j] < compB[j]:
                velA[j] += 1
                velB[j] -= 1

    moonETotTot = 0
    for moonId in moonPos:
        moonEPot = 0
        moonEKin = 0
        for j in range(3):
            moonPos[moonId][j] += moonVel[moonId][j]
            moonEPot += abs(moonPos[moonId][j])
            moonEKin += abs(moonVel[moonId][j])
        moonETot = moonEPot * moonEKin
        if i == 999:
            print("ETot, ",moonId, moonETot)
        moonETotTot += moonETot

print(moonPos)
print(moonVel)
print(moonETotTot)

# %%
from copy import deepcopy


for i in range(10000000):
    if i == 5000000:
        print("")
    if not i%1000000:
        print(i, ' - ', end='')
    if not i%100000:
        print('.', end='')
        
        
        
    perms = itertools.combinations(moonPos,2)
    for moonPerm in perms:
        compA = moonPos[moonPerm[0]]
        compB = moonPos[moonPerm[1]]
        velA  = moonVel[moonPerm[0]]
        velB  = moonVel[moonPerm[1]]

        for j in range(3):
            if compA[j] > compB[j]:
                velA[j] -= 1
                velB[j] += 1
            elif compA[j] < compB[j]:
                velA[j] += 1
                velB[j] -= 1

    moonETotTot = 0
    for moonId in moonPos:
        moonEPot = 0
        moonEKin = 0
        for j in range(3):
            moonPos[moonId][j] += moonVel[moonId][j]
            moonEPot += abs(moonPos[moonId][j])
            moonEKin += abs(moonVel[moonId][j])
        moonETot = moonEPot * moonEKin
        moonETotTot += moonETot
    
    
    ### PART 2 ###
    
    allX = []
    allY = []
    allZ = []
    
    for moonId in moonPos:
        moon = moonPos[moonId]
        allX.append(moon[0])
        allY.append(moon[1])
        allZ.append(moon[2])
    
    if allX == allX1:
        print("X",i)
        
    if allY == allY1:
        print("Y",i)
        
    if allZ == allZ1:
        print("Z",i)
    
    
    
    if setBreak:
        break
        
    
print("DONE")

# %%
'''
Z 102354
Z 102355
Y 193050
Y 193051
Z 204710
Z 204711
X 268294
X 268295
'''

fixConst = [102355, 193051, 268295]

def primes(n):
    primfac = []
    d = 2
    while d*d <= n:
        while (n % d) == 0:
            primfac.append(d)  # supposing you want multiple factors repeated
            n //= d
        d += 1
    if n > 1:
        primfac.append(n)
    return primfac

for cconst in fixConst:
    cprimfac = primes(cconst)
    print(cprimfac)

    
result = 5 * 11 * 23 * 1861 * 2333 * 193051

print(result)
